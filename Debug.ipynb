# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import sys
import matplotlib.pyplot as plt
import librosa
from IPython.display import Audio
PATH = "/home/tskrzypczak/Desktop/dataset_voice/chinese/"

# %%
sample_voice = os.listdir(PATH)[2]

# %%
sv_path = os.path.join(PATH, sample_voice)

# %%
Audio(sv_path, autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spol_path = "/home/tskrzypczak/Desktop/dataset_voice/validation/polish_0.wav" 
Audio(spol_path, autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
from librosa.display import specshow

# %%
loaded_voice, sr = librosa.core.load(sv_path, sr=None)

# %%
# Adding white noise 
wn = np.random.randn(len(loaded_voice))
data_wn = loaded_voice + 0.005*wn
plot_time_series(data_wn)
# We limited the amplitude of the noise so we can still hear the word even with the noise, 
#which is the objective
Audio(data_wn, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from ai_module.preprocessing.tf_dataset import get_val_dataset, get_dataset
from ai_module.preprocessing.features_maps_function import factory_melspec_feature

melspec_feature_mapping = factory_melspec_feature(64, 44100)
dt = get_dataset(melspec_feature_mapping, 1)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function create_dataset.<locals>.<lambda> at 0x7f86e4f4bb70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function create_dataset.<locals>.<lambda> at 0x7f86e4f4bb70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...

# %%
val_dt = get_val_dataset(melspec_feature_mapping, 1)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function create_dataset.<locals>.<lambda> at 0x7f86e519d598> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function create_dataset.<locals>.<lambda> at 0x7f86e519d598> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...

# %%
for sample, label in val_dt.take(100):
    print(label)
# Out:
# tf.Tensor(b'/home/tskrzypczak/Desktop/dataset_voice/validation/polish_917.wav', shape=(), dtype=string)
# tf.Tensor([3], shape=(1,), dtype=int32)
# tf.Tensor(b'/home/tskrzypczak/Desktop/dataset_voice/validation/polish_72.wav', shape=(), dtype=string)
# tf.Tensor([3], shape=(1,), dtype=int32)
# tf.Tensor(b'/home/tskrzypczak/Desktop/dataset_voice/validation/russian_1153.wav', shape=(), dtype=string)
# tf.Tensor([4], shape=(1,), dtype=int32)
# tf.Tensor(b'/home/tskrzypczak/Desktop/dataset_voice/validation/chinese_788.wav', shape=(), dtype=string)
# tf.Tensor([0], shape=(1,), dtype=int32)
# tf.Tensor(b'/home/tskrzypczak/Desktop/dataset_voice/validation/english_525.wav', shape=(), dtype=string)
# tf.Tensor([1], shape=(1,), dtype=int32)
# tf.Tensor(b'/home/tskrzypczak/Desktop/dataset_voice/validation/russian_440.wav', shape=(), dtype=string)
# tf.Tensor([4], shape=(1,), dtype=int32)
# tf.Tensor(b'/home/tskrzypczak/Desktop/dataset_voice/validation/polish_698.wav', shape=(), dtype=string)
# ...

# %%
import tensorflow_io as tfio
import librosa.display

for sample, label in dt.take(1):
    sample = sample.numpy()
    dims = sample[0].shape
    print(dims)
    librosa.display.specshow(sample[0].reshape(dims[:2]), x_axis='time', y_axis='mel', sr=44100, fmax=12000)
# Out:
# tf.Tensor(b'/home/tskrzypczak/Desktop/dataset_voice/english/english2321.wav', shape=(), dtype=string)
# (64, 431, 1)

# %%
sample.numpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-43666cf00d36> in <module>
# ----> 1 sample.numpy()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'numpy'

# %%
from ai_module.preprocessing.features_maps_function import make_melspec_feature
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-a6a285c3a3e8> in <module>
# ----> 1 from ai_module.preprocessing.features_maps_function import make_melspec_feature
#
# ImportError: cannot import name 'make_melspec_feature'

# %%
def plot_time_series(data):
    fig = plt.figure(figsize=(14, 8))
    plt.title('Raw wave ')
    plt.ylabel('Amplitude')
    plt.plot(np.linspace(0, 1, len(data)), data)
    plt.show()

# %%
plot_time_series(loaded_voice)

# %%
spect = make_melspec_feature(loaded_voice, sr, 128)
spect = spect.reshape((128, -1))

librosa.display.specshow(spect, x_axis='time',
                          y_axis='mel', sr=sr,
                          fmax=12000)

# %%
module_path = os.path.abspath(os.path.join('./ai_module'))
print(module_path)

if module_path not in sys.path:
    sys.path.append(module_path)

# import ai_module.preprocessing
# Out:
# /home/tskrzypczak/Desktop/ai_module

# %%
import .ai_module
# Out:
#   File "<ipython-input-40-54b47640015d>", line 1
#     import .ai_module
#            ^
# SyntaxError: invalid syntax

# %%
# !pwd
# Out:
# /home/tskrzypczak/Desktop

# %%
cd LanguageDetection/
# Out:
# /home/tskrzypczak/Documents/ADLProject/LanguageDetection

# %%
ls
# Out:
# ai_module/  LICENSE       README.md       webapp/
# config.py   __pycache__/  Untitled.ipynb

# %%
pip3 install matplotlib
# Out:
#   File "<ipython-input-63-f73546985525>", line 1
#     pip3 install matplotlib
#                ^
# SyntaxError: invalid syntax
